# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\spred\\OneDrive\\Documents\\ifood_df.csv")
df
# Out:
#        Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0     58138.0        0         0       58       635         88
# 1     46344.0        1         1       38        11          1
# 2     71613.0        0         0       26       426         49
# 3     26646.0        1         0       26        11          4
# 4     58293.0        1         0       94       173         43
# ...       ...      ...       ...      ...       ...        ...
# 2200  61223.0        0         1       46       709         43
# 2201  64014.0        2         1       56       406          0
# 2202  56981.0        0         0       91       908         48
# 2203  69245.0        0         1        8       428         30
# 2204  52869.0        1         1       40        84          3
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 0                 546              172                88            88  ...
# ...

# %%
df.isnull().sum()
# Out:
# Income                  0
# Kidhome                 0
# Teenhome                0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# Age                     0
# Customer_Days           0
# marital_Divorced        0
# marital_Married         0
# marital_Single          0
# marital_Together        0
# marital_Widow           0
# education_2n Cycle      0
# education_Basic         0
# education_Graduation    0
# education_Master        0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(184)

# %%
df[df.duplicated()]
# Out:
#        Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 77    38620.0        0         0       56       112         17
# 167   78497.0        0         0       44       207         26
# 267   51369.0        0         1       84       297          7
# 268   37760.0        0         0       20        84          5
# 346   37717.0        1         0       31         9          0
# ...       ...      ...       ...      ...       ...        ...
# 2185  22775.0        1         0       40         5          1
# 2188  75777.0        0         0       12       712         26
# 2192  58554.0        1         1       55       368         24
# 2199  34421.0        1         0       81         3          3
# 2201  64014.0        2         1       56       406          0
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 77                 44               34                22            89  ...
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#        Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0     58138.0        0         0       58       635         88
# 1     46344.0        1         1       38        11          1
# 2     71613.0        0         0       26       426         49
# 3     26646.0        1         0       26        11          4
# 4     58293.0        1         0       94       173         43
# ...       ...      ...       ...      ...       ...        ...
# 2198  26816.0        0         0       50         5          1
# 2200  61223.0        0         1       46       709         43
# 2202  56981.0        0         0       91       908         48
# 2203  69245.0        0         1        8       428         30
# 2204  52869.0        1         1       40        84          3
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 0                 546              172                88            88  ...
# ...

# %%
df.shape
# Out:
# (2021, 39)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2021 entries, 0 to 2204
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Income                2021 non-null   float64
#  1   Kidhome               2021 non-null   int64
#  2   Teenhome              2021 non-null   int64
#  3   Recency               2021 non-null   int64
#  4   MntWines              2021 non-null   int64
#  5   MntFruits             2021 non-null   int64
#  6   MntMeatProducts       2021 non-null   int64
#  7   MntFishProducts       2021 non-null   int64
#  8   MntSweetProducts      2021 non-null   int64
#  9   MntGoldProds          2021 non-null   int64
#  10  NumDealsPurchases     2021 non-null   int64
#  11  NumWebPurchases       2021 non-null   int64
#  12  NumCatalogPurchases   2021 non-null   int64
#  13  NumStorePurchases     2021 non-null   int64
#  14  NumWebVisitsMonth     2021 non-null   int64
# ...

# %%
df.describe()
# Out:
#               Income      Kidhome     Teenhome      Recency     MntWines  \
# count    2021.000000  2021.000000  2021.000000  2021.000000  2021.000000
# mean    51687.258783     0.443345     0.509649    48.880752   306.492331
# std     20713.046401     0.536196     0.546393    28.950917   337.603877
# min      1730.000000     0.000000     0.000000     0.000000     0.000000
# 25%     35416.000000     0.000000     0.000000    24.000000    24.000000
# 50%     51412.000000     0.000000     0.000000    49.000000   178.000000
# 75%     68274.000000     1.000000     1.000000    74.000000   507.000000
# max    113734.000000     2.000000     2.000000    99.000000  1493.000000
#
#          MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# count  2021.000000      2021.000000      2021.000000       2021.000000
# mean     26.364671       166.059871        37.603662         27.268679
# std      39.776518       219.869126        54.892196         41.575454
# ...

# %%
#remove Z_CostContact and Z_revenue colums which is not required
df.shape
# Out:
# (2021, 37)

# %%
df['MntTotal']=(df["MntWines"]+df["MntFruits"]+df["MntMeatProducts"]+df["MntFishProducts"]+df["MntSweetProducts"]+df["MntGoldProds"])

# %%
df[['Income','Age','Recency','MntTotal']].mean()
# Out:
# Income      51687.258783
# Age            51.117269
# Recency        48.880752
# MntTotal      607.711034
# dtype: float64

# %%
df[['NumWebPurchases','NumStorePurchases','NumCatalogPurchases']].mean()
# Out:
# NumWebPurchases        4.115289
# NumStorePurchases      5.807521
# NumCatalogPurchases    2.644730
# dtype: float64

# %%
df['AcceptedCmpOverall'].value_counts()
# Out:
# AcceptedCmpOverall
# 0    1595
# 1     301
# 2      75
# 3      40
# 4      10
# Name: count, dtype: int64

# %%
features = [
    'Income',
    'Recency',
    'MntTotal',
    'NumWebPurchases',
    'NumStorePurchases',
    'NumCatalogPurchases',
    'AcceptedCmpOverall'
]

X = df[features]
X
# Out:
#        Income  Recency  MntTotal  NumWebPurchases  NumStorePurchases  \
# 0     58138.0       58      1617                8                  4
# 1     46344.0       38        27                1                  2
# 2     71613.0       26       776                8                 10
# 3     26646.0       26        53                2                  4
# 4     58293.0       94       422                5                  6
# ...       ...      ...       ...              ...                ...
# 2198  26816.0       50        22                0                  3
# 2200  61223.0       46      1341                9                  4
# 2202  56981.0       91      1241                2                 13
# 2203  69245.0        8       843                6                 10
# 2204  52869.0       40       172                3                  4
#
#       NumCatalogPurchases  AcceptedCmpOverall
# 0                      10                   0
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
df.columns.tolist()
# Out:
# ['Income',
#  'Kidhome',
#  'Teenhome',
#  'Recency',
#  'MntWines',
#  'MntFruits',
#  'MntMeatProducts',
#  'MntFishProducts',
#  'MntSweetProducts',
#  'MntGoldProds',
#  'NumDealsPurchases',
#  'NumWebPurchases',
#  'NumCatalogPurchases',
#  'NumStorePurchases',
#  'NumWebVisitsMonth',
#  'AcceptedCmp3',
#  'AcceptedCmp4',
#  'AcceptedCmp5',
#  'AcceptedCmp1',
#  'AcceptedCmp2',
#  'Complain',
#  'Response',
#  'Age',
#  'Customer_Days',
#  'marital_Divorced',
#  'marital_Married',
#  'marital_Single',
#  'marital_Together',
#  'marital_Widow',
#  'education_2n Cycle',
#  'education_Basic',
#  'education_Graduation',
#  'education_Master',
#  'education_PhD',
#  'MntTotal',
#  'MntRegularProds',
#  'AcceptedCmpOverall']

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

# %%
plt.figure(figsize=(8,5))
plt.plot(range(1,11), wcss)
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.title("Elbow Method for Optimal Clusters")
plt.show()

# %%
kmeans = KMeans(n_clusters=5, random_state=42)
df['Cluster'] = kmeans.fit_predict(X_scaled)

# %%
import seaborn as sns
plt.figure(figsize=(8,6))
sns.scatterplot(
    x=df['Income'],
    y=df['MntTotal'],
    hue=df['Cluster'],
    palette='Set1'
)
plt.title("Customer Segmentation based on Income and Spending")
plt.show()

# %%
df.groupby('Cluster')['MntTotal'].mean().plot(kind='bar')
plt.title("Average Total Spending per Cluster")
plt.ylabel("Spending")
plt.show()

# %%
cluster_summary = df.groupby('Cluster')[features].mean()
cluster_summary
# Out:
#                Income    Recency     MntTotal  NumWebPurchases  \
# Cluster
# 0        33476.013944  25.163347    95.063745         2.053785
# 1        80155.231405  48.495868  1552.537190         5.644628
# 2        36641.589583  75.456250   125.952083         2.393750
# 3        59198.031683  44.956436   717.615842         6.657426
# 4        73785.082324  51.733656  1379.544794         5.065375
#
#          NumStorePurchases  NumCatalogPurchases  AcceptedCmpOverall
# Cluster
# 0                 3.177291             0.539841            0.093625
# 1                 8.107438             6.115702            2.495868
# 2                 3.468750             0.693750            0.085417
# 3                 7.704950             2.740594            0.182178
# 4                 8.728814             6.336562            0.312349

# %%
df['Cluster'].value_counts()
# Out:
# Cluster
# 3    505
# 0    502
# 2    480
# 4    413
# 1    121
# Name: count, dtype: int64

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\spred\\OneDrive\\Documents\\ifood_df.csv")
df.drop_duplicates(inplace=True)
df.drop(['Z_CostContact','Z_Revenue'],axis=1,inplace=True)
df.to_csv("C:\\Users\\spred\OneDrive\Documents\\cleaned_ifood_df.csv",index=False)
